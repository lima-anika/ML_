# %% [markdown]
# # Linear_regression

# %%
import pandas as pd

df = pd.read_csv("price_weight.csv")
df
# Out:
#    weight  price
# 0       2     35
# 1       4     60
# 2       5     20
# 3       3     50
# 4       6     50
# 5       5     55
# 6       7     60

# %%
df.head()
# Out:
#    weight  price
# 0       2     35
# 1       4     60
# 2       5     20
# 3       3     50
# 4       6     50

# %%
x = df.drop("price", axis='columns')
x
# Out:
#    weight
# 0       2
# 1       4
# 2       5
# 3       3
# 4       6
# 5       5
# 6       7

# %%
y=df.drop(df[['weight']],axis=1)

x=df.drop(df[['price']],axis=1)

y

x
# Out:
#    weight
# 0       2
# 1       4
# 2       5
# 3       3
# 4       6
# 5       5
# 6       7

# %%
x
y.shape
# Out:
# (7, 1)

# %%
x
# Out:
#    weight
# 0       2
# 1       4
# 2       5
# 3       3
# 4       6
# 5       5
# 6       7

# %%
x.shape
# Out:
# (7, 1)

# %%
y.shape
# Out:
# (7, 1)

# %% [markdown]
# # plotting weight and prices in x,y axis

# %%
import matplotlib.pyplot as plt

plt.scatter(x,y)

plt.title("Plotting Price Prediction Model")
 
# Setting the X and Y labels
plt.xlabel('Weight in X axis')
plt.ylabel('Price in Y axis')

plt.show()

# %%
xm=(x.mean())
xm

f_xm=float(xm)

f_xm
# Out:
# 4.571428571428571

# %%
ym=(y.mean())
ym

f_ym=float(ym)

f_ym
# Out:
# 47.142857142857146

# %%
df['multiplication'] = df['weight'] * df['price']

print(df['multiplication'])
# Out:
# 0     70
# 1    240
# 2    100
# 3    150
# 4    300
# 5    275
# 6    420
# Name: multiplication, dtype: int64

# %%
mul=df['multiplication'] 

mul
# Out:
# 0     70
# 1    240
# 2    100
# 3    150
# 4    300
# 5    275
# 6    420
# Name: multiplication, dtype: int64

# %%
sum_xy=sum(mul)

mean_xy=mul.mean()

mean_xy
# Out:
# 222.14285714285714

# %%
sqr_x=df['weight']*df['weight']
sqr_x
# Out:
# 0     4
# 1    16
# 2    25
# 3     9
# 4    36
# 5    25
# 6    49
# Name: weight, dtype: int64

# %%
mean_x_sqr=sqr_x.mean()

mean_x_sqr
# Out:
# 23.428571428571427

# %%
x_bar_sqr=xm*xm

x_bar_sqr
# Out:
# weight    20.897959
# dtype: float64

# %% [markdown]
# # finding co-efficient

# %%
M=((f_ym*f_xm)-mean_xy)/((x_bar_sqr)-(mean_x_sqr))

M
# Out:
# weight    2.620968
# dtype: float64

# %% [markdown]
# # finding Intercept

# %%
c=f_ym-(M*f_xm)

c

c=float(c)
c
# Out:
# 35.161290322580655

# %% [markdown]
# # prediction:

# %%
y_predict=M*(6)+c

y_predict
# Out:
# weight    50.887097
# dtype: float64

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import *
from pylab import *


plt.plot(x,M*x+c,color='yellow')

plt.scatter(x,y,color='magenta')

xlabel('Weight in X axis')
ylabel('Price in Y axis')
# Out:
# Text(0, 0.5, 'Price in Y axis')

# %%
yp=M*x+c

yp
# Out:
#       weight
# 0  40.403226
# 1  45.645161
# 2  48.266129
# 3  43.024194
# 4  50.887097
# 5  48.266129
# 6  53.508065

# %%
list_y = df['price'].tolist()
list_y[0]
# Out:
# 35

# %%
df['yp'] = yp
df
list_yp = df['yp'].tolist()
list_yp


list_yp[0] 

df.drop(['yp'], axis=1)
df
# Out:
#    weight  price  multiplication         yp
# 0       2     35              70  40.403226
# 1       4     60             240  45.645161
# 2       5     20             100  48.266129
# 3       3     50             150  43.024194
# 4       6     50             300  50.887097
# 5       5     55             275  48.266129
# 6       7     60             420  53.508065

# %%
siz=len(list_yp)

res=[]

for i in range(siz):
    
    print(list_y[i])
    
    
    print(list_yp[i])
        
    ft=list_y[i]-list_yp[i]
    
    res.append(ft)
    
    print(ft)
# Out:
# 35
# 40.40322580645162
# -5.403225806451623
# 60
# 45.64516129032259
# 14.35483870967741
# 20
# 48.26612903225807
# -28.26612903225807
# 50
# 43.0241935483871
# 6.975806451612897
# 50
# 50.88709677419355
# -0.8870967741935516
# 55
# 48.26612903225807
# 6.733870967741929
# 60
# 53.50806451612904
# 6.491935483870961

# %% [markdown]
# # calculate MSE

# %%
s=0

for i in range(siz):
    
    sqr=res[i]*res[i]
    
    s=s+sqr
    
print(s)


MAE=s/siz

MAE
# Out:
# 1171.1693548387098
# 167.30990783410138

# %% [markdown]
# # Calculate MAE

# %%
s=0

for i in range(siz):
    
    s=s+abs(res[i])
    
print(s)


MAE=s/siz

MAE
# Out:
# 9.87327188940092
